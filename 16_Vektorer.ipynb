# %% [markdown]
# ### Vektorer
#
# Lag et program i Python som tegner ut  av en vektor $ v ⃗  =  [x ,y]  =  [3  ,4]$

# %%
from matplotlib.pyplot import*
from numpy import*

# Vektor opprinnelse plassering 
X = [0] 
Y = [0] 

# Lag en posisjonsvektor
v = array([3,4])

# Lag plottet
fig, ax = subplots()

# Legg til vektoren v til plottet
ax.quiver(X, Y, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r')
title('Posisjonsvektor')

# Angi x-grenser og y-grenser for plottet
ax.set_xlim([-1, 5])
ax.set_ylim([-1, 5])

# Tegn x-aksen og y-aksen
axhline(color = 'black')
axvline(color = 'black')

# Vis plottet sammen med rutenettet
grid()
show()

# %% [markdown]
# #### Lengden av en vektor
#
# Lag et program i Python som regner ut lengden av en vektor $u ⃗  =  [x ,y]$.
#
# Bruk programmet til å finne lengden av vektoren $ u ⃗  =  [3  ,4]$.

# %%
from numpy import *

u = array([3,4])                                 # Skriv vektoren
lengde = sqrt(u[0]**2 + u[1]**2)                 # Lengden av vektor OA

# Skriv vektoren u og lengden av u i konsollen
print()
print(f'u = {u}')
print()
print(f'1. Lengden av vektoren u = {lengde:.2f}')
print()

# Bestem lengden av en vektor med kommando linlag.norm()
print(f'2. Lengden av vektoren u = {linalg.norm(u):.2f}')
# Out:
# u = [3 4]
#
# 1. Lengden av vektoren u = 5.00
#
# 2. Lengden av vektoren u = 5.00

# %%
from matplotlib.pyplot import*
from numpy import*

# Vektor opprinnelse plassering 
X = [0] 
Y = [0] 

# Lag multippelvektorer
v = array([2 , 3])
u = array([5 , 1])
w = array([v[0] + u[0] , v[1] + u[1]])        # Summen av to vektorer

# Lag plottet
fig, ax = subplots()

# Legg til vektorene til plottet
ax.quiver(X, Y, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r')
ax.quiver(X, Y, u[0], u[1], angles='xy', scale_units='xy', scale=1, color='b')
ax.quiver(X, Y, w[0], w[1], angles='xy', scale_units='xy', scale=1, color='g')
title('Addisjon av to vektorer')

# Angi x-grenser og y-grenser for plottet
ax.set_xlim([-1, 8])
ax.set_ylim([-1, 5])

# Tegn x-aksen og y-aksen
axhline(color = 'black')
axvline(color = 'black')

# Vis plottet sammen med rutenettet
grid()
show()
print(f'w = {w}')
# Out:
# w = [7 4]

# %%
from matplotlib.pyplot import*
from numpy import*

# Vektor opprinnelse plassering 
X1 = [1] 
Y1 = [6] 
X2 = [5]
Y2 = [2]

# Lag vektoren mellom to punkterne
w = array([X2[0] - X1[0] , Y2[0] - Y1[0]])     

# Lag plottet
fig, ax = subplots()

# Legg til vektoren til plottet
ax.quiver(X1, Y1, w[0], w[1], angles='xy', scale_units='xy', scale=1, color='g')
title('Vektoren mellom to punkter')

# Angi x-grenser og y-grenser for plottet
ax.set_xlim([-1, 7])
ax.set_ylim([-1, 7])

# Tegn x-aksen og y-aksen
axhline(color = 'black')
axvline(color = 'black')

# Vis plottet sammen med rutenettet
grid()
show()
print(f'w = {w}')
# Out:
# w = [ 4 -4]

# %%
from matplotlib.pyplot import*
from numpy import*

# Vektor opprinnelse plassering 
X = [0] 
Y = [0] 

# Lag multippelvektorer
v = array([2 , 3])
u = array([5 , 1])
w = array([u[0] - v[0] , u[1] - v[1]])        # Subtraksjon av to vektorer

# Lag plottet
fig, ax = subplots()

# Legg til vektorene til plottet
ax.quiver(X, Y, v[0], v[1], angles='xy', scale_units='xy', scale=1, color='r')
ax.quiver(X, Y, u[0], u[1], angles='xy', scale_units='xy', scale=1, color='b')
ax.quiver(v[0], v[1], w[0], w[1], angles='xy', scale_units='xy', scale=1, color='g')
title('Subtraksjon av to vektorer')

# Angi x-grenser og y-grenser for plottet
ax.set_xlim([-1, 6])
ax.set_ylim([-1, 4])

# Tegn x-aksen og y-aksen
axhline(color = 'black')
axvline(color = 'black')

# Vis plottet sammen med rutenettet
grid()
show()
print(f'w = {w}')
# Out:
# w = [ 3 -2]
